# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.randint(-100, 100, 50).cumsum()
print(data)

# 그래프 출력
plt.plot(range(50),data, 'r^')
plt.title('Stock')
plt.ylabel('Value')
plt.xlabel('Time(min)')
# Out:
# [ -34   33   -2   71   90  118  159  237  250  211  276  200  138   65
#   -16    9  -89  -87 -132 -160 -221 -145 -100  -19   36  -12   50  -47
#    45   17   80  174  104  159  164   94  137  151   56  112   64  -32
#   -31 -107 -109 -175 -109  -90 -160 -142]
# Text(0.5, 0, 'Time(min)')

# %%
import matplotlib.font_manager as fm
path = 'NanumBarunGothicLight.ttf'
fontprop=fm.FontProperties(fname=path,size=12)
data = np.random.randint(-100, 100, 50).cumsum()
plt.plot(range(50),data, 'r^')
plt.title('주식 변동 그래프',fontproperties=fontprop)
plt.ylabel('주가',fontproperties=fontprop)
plt.xlabel('시간(min)',fontproperties=fontprop)
# Out:
# Text(0.5, 0, '시간(min)')
# Error in callback <function _draw_all_if_interactive at 0x0000023F85FED120> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Anaconda\Lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File c:\Anaconda\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Anaconda\Lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# -> 2082         self.draw(*args, **kwargs)
#
# ...

# %%
#2 matplotlib.rcParams로 설정

# %%
[ (file.name, file.fname) for file in fm.fontManager.ttflist if 'Nanum' in file.name]
# Out:
# [('NanumSquareRound',
#   'C:\\Users\\js2-3\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundEB.ttf'),
#  ('Nanum Brush Script',
#   'C:\\Users\\js2-3\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBrush.ttf'),
#  ('NanumSquareRound',
#   'C:\\Users\\js2-3\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundL.ttf'),
#  ('NanumSquareRound',
#   'C:\\Users\\js2-3\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundB.ttf'),
#  ('Nanum Pen Script',
#   'C:\\Users\\js2-3\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumPen.ttf'),
#  ('NanumSquareRound',
#   'C:\\Users\\js2-3\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareRoundR.ttf')]

# %%
plt.rcParams['font.family'] = 'Nanum Brush Script'
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.size'] = 17

# %%
data = np.random.randint(-100, 100, 50).cumsum()
plt.plot(range(50),data, 'r^')
plt.title('Stock')
plt.ylabel('Value')
plt.xlabel('Time(min)')
# Out:
# Text(0.5, 0, 'Time(min)')

# %%
import matplotlib
print('설정파일 위치:',matplotlib.matplotlib_fname())
# Out:
# 설정파일 위치: c:\Users\js2-3\anaconda3\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
import matplotlib.pyplot as plt
print(plt.rcParams['font.family'])
print(plt.rcParams['font.size'])
# Out:
# ['Nanum Brush Script']
# 17.0

# %%
import matplotlib.font_manager as fm
data = np.random.randint(-100, 100, 50).cumsum()
plt.plot(range(50),data, 'r*')
plt.title('주식 변동 그래프')
plt.ylabel('주가')
plt.xlabel('시간(min)')
# Out:
# Text(0.5, 0, '시간(min)')
